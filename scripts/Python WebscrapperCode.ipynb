# %% [markdown]
# # **AUTO**

# %%
import pandas as pd

df_a = pd.read_csv('/content/Classe_A_per_principio_attivo_15-10-2024.csv', encoding='latin1', delimiter=';')
df_h = pd.read_csv('/content/Classe_H_per_principio_attivo_15-10-2024.csv', encoding='latin1', delimiter=';')

df_a['Class'] = 'A'
df_h['Class'] = 'H'

combined = pd.concat([df_a, df_h], ignore_index=True)
combined.to_csv('combined.csv', index=False)

# %%
df = pd.read_csv('/content/combined.csv', encoding='latin1')
# Remove empty rows (rows where all elements are NaN)
df_cleaned = df.dropna(how='all')

# Remove duplicate rows
df_cleaned = df_cleaned.drop_duplicates()

# Save the cleaned dataset to a new CSV file
df_cleaned.to_csv('/content/combined-csv_cleaned.csv', index=False)

print("Dataset cleaned and saved as 'cleaned_combined_csv.csv'")
# Out:
# Dataset cleaned and saved as 'cleaned_combined_csv.csv'

# %%
# After cleaning and removing duplicates
df_cleaned.to_csv('/content/combined-csv_cleaned.csv', index=False)

# Reload cleaned dataset (optional, if you want to simulate a fresh start)
df_cleaned = pd.read_csv('/content/combined-csv_cleaned.csv', encoding='latin1')

# Filter rows by index (from 6437 to 6767 inclusive)
filtered_df = df_cleaned.loc[6435:6767]

# Save the filtered dataset
filtered_df.to_csv('/content/filtered_combined.csv', index=False)

print("Filtered dataset saved as 'filtered_combined.csv'")


# List of keywords or partial column names to keep (case-insensitive)
columns_to_keep = [
    'principio attivo',
    'descrizione gruppo',
    'denominazione e confezione',
    'titolare aic',
    'aic',
    'codice gruppo equivalenza',
    'class'
]

# Normalize column names in df to lowercase for matching
columns_lower = [col.lower() for col in filtered_df.columns]

# Normalize target columns to lowercase
columns_to_keep_lower = [col.lower() for col in columns_to_keep]

# Select columns from filtered_df that match (case-insensitive)
selected_columns = [filtered_df.columns[i] for i, col in enumerate(columns_lower) if col in columns_to_keep_lower]

# Create new DataFrame with selected columns
final_df = filtered_df[selected_columns]

# Save to CSV
final_df.to_csv('/content/final_filtered_combined.csv', index=False)

print("Final filtered dataset saved as 'final_filtered_combined.csv'")
# Out:
# Filtered dataset saved as 'filtered_combined.csv'
# Final filtered dataset saved as 'final_filtered_combined.csv'

# %%
import requests
import pandas as pd  # if you use pandas elsewhere


HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36",
    "Accept": "application/json"
}

def get_codice_sis(aic_code):
    try:
        aic_int = int(float(aic_code))          # Convert code to int to remove decimals
        aic_code_str = str(aic_int).zfill(9)   # Then zero-pad to 9 digits
    except:
        aic_code_str = str(aic_code)            # If conversion fails, keep original as string


    search_url = f"https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query={aic_code_str}&spellingCorrection=true&page=0"
    print(f"Trying URL: {search_url}")
    try:
        response = requests.get(search_url, headers=HEADERS, timeout=5)
        print(f"Status code: {response.status_code}")  # <-- print HTTP response status
        print(f"Content-Type: {response.headers.get('Content-Type')}")  # <-- print content type
        print(f"Response snippet: {response.text[:200]}")  # <-- print first 200 chars of response text

        if "application/json" not in response.headers.get("Content-Type", ""):
            print(f"⚠️ Response is not JSON for AIC {aic_code}")
            return None

        data = response.json()

        if not data.get("data") or not data["data"].get("content"):
            print(f"⚠️ No data found for AIC {aic_code}")
            return None

        medicinale = data["data"]["content"][0].get("medicinale")
        if not medicinale:
            print(f"⚠️ No medicinale info for AIC {aic_code}")
            return None

        codice_sis = medicinale.get("codiceSis")
        return codice_sis

    except Exception as e:
        print(f"❌ Error for AIC {aic_code}: {e}")
        return None

# Assuming final_df is the DataFrame from previous steps with selected columns
# Rename the column that contains the AIC code to a consistent name for this code:
# You mentioned 'AIC Code (AIC)' is the exact column name, so let's rename it to 'AIC' for easier use
final_df = final_df.rename(columns={'AIC Code (AIC)': 'AIC'})

# Make sure 'AIC' column is string and zero-padded to 9 digits
final_df['AIC'] = final_df['AIC'].astype(str).str.zfill(9)

# Apply the API function to get codiceSis
final_df['codiceSis'] = final_df['AIC'].apply(get_codice_sis)

# Log all AIC codes that returned no codiceSis (None/NaN)
missing_aics = final_df[final_df['codiceSis'].isna()]['AIC'].tolist()
print(f"AIC codes with no results: {missing_aics}")

# Drop rows without codiceSis (None or NaN)
df_clean = final_df.dropna(subset=['codiceSis']).copy()

# Trim AIC code to first 5 digits
df_clean['AIC_trimmed'] = df_clean['AIC'].str[:5]

# Clean codiceSis to string integer form (remove decimal if present)
# Clean codiceSis to string integer form and zero-pad to 6 digits
def clean_codiceSis(code):
    try:
        return str(int(float(code))).zfill(6)  # zero-pad to 6 digits
    except:
        return str(code)

df_clean['codiceSis_clean'] = df_clean['codiceSis'].apply(clean_codiceSis)

# Trim AIC to 6 digits (the first 6 digits, as required by API)
df_clean['AIC_trimmed'] = df_clean['AIC'].str[:6]  # or .str[-6:] if last 6 digits needed

# Now build the URL column using the cleaned and trimmed codes
df_clean['URL'] = (
    "https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/organizzazione/"
    + df_clean['codiceSis_clean']
    + "/farmaci/"
    + df_clean['AIC_trimmed']
    + "/stampati?ts=RCP"
)

# Drop intermediate columns before saving or further processing
df_clean = df_clean.drop(columns=['codiceSis_clean', 'AIC_trimmed'])


# Save the final dataset with URLs
df_clean.to_csv('/content/final_filtered_dataset_with_urls.csv', index=False)

print(f"Dropped {len(final_df) - len(df_clean)} rows without codiceSis.")
print(f"Saved dataset with URLs, total rows: {len(df_clean)}")
# Out:
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=036160188&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000036778","principiAttiviIt":["OCTOCOG ALFA"],"confezioni":[{"idPackage":"73351","denominazionePackage":"500 UI POLVERE E SOLVENTE PER SOLUZIONE INIETTABILE 1
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=036160152&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000036781","principiAttiviIt":["OCTOCOG ALFA"],"confezioni":[{"idPackage":"73354","denominazionePackage":"\"2000 UI POLVERE E SOLV.PER SOLUZ.INETTABILE-USO END
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=036160164&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000036782","principiAttiviIt":["OCTOCOG ALFA"],"confezioni":[{"idPackage":"73355","denominazionePackage":"\"3000 UI POLVERE E SOLV.PER SOLUZ.INETTABILE-USO END
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=028687010&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000066681","principiAttiviIt":["OCTOCOG ALFA"],"confezioni":[{"idPackage":"34059","denominazionePackage":"\"250 U.I./10 ML POLVERE E SOLVENTE PER SOLUZIONE INI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=028687022&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000066682","principiAttiviIt":["OCTOCOG ALFA"],"confezioni":[{"idPackage":"34060","denominazionePackage":"\"500 U.I./10 ML POLVERE E SOLVENTE PER SOLUZIONE INI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=028687034&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000066683","principiAttiviIt":["OCTOCOG ALFA"],"confezioni":[{"idPackage":"34061","denominazionePackage":"\"1000 U.I./10 ML POLVERE E SOLVENTE PER SOLUZIONE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039100045&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000042520","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"103302","denominazionePackage":"\"0,05 MG/ML SOLUZIONE INIETTABILE IN SIRINGA PRE-RIEM
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039101047&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000042523","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"103317","denominazionePackage":"\"0,1 MG/ML SOLUZIONE INIETTABILE IN SIRINGA PRE-RIEMP
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041156023&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000046442","principiAttiviIt":["OCTREOTIDE ACETATO","OCTREOTIDE"],"confezioni":[{"idPackage":"127362","denominazionePackage":"\"0,1 MG/1 ML SOLUZIONE INIETTABI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039100019&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000042520","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"103302","denominazionePackage":"\"0,05 MG/ML SOLUZIONE INIETTABILE IN SIRINGA PRE-RIEM
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039101011&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000042522","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"103314","denominazionePackage":"\"0,05 MG/ML SOLUZIONE INIETTABILE IN SIRINGA PRE-RIEM
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041156011&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000046441","principiAttiviIt":["OCTREOTIDE ACETATO","OCTREOTIDE"],"confezioni":[{"idPackage":"127361","denominazionePackage":"\"0,05 MG/1 ML SOLUZIONE INIETTAB
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040014045&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044196","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"111897","denominazionePackage":"\"1 MG/5 ML SOLUZIONE INIETTABILE O CONCENTRATO PER SO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041156047&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000046444","principiAttiviIt":["OCTREOTIDE ACETATO","OCTREOTIDE"],"confezioni":[{"idPackage":"127364","denominazionePackage":"\"1 MG/5 ML SOLUZIONE INIETTABILE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039100072&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000042520","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"103302","denominazionePackage":"\"0,05 MG/ML SOLUZIONE INIETTABILE IN SIRINGA PRE-RIEM
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039101074&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000042522","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"103314","denominazionePackage":"\"0,05 MG/ML SOLUZIONE INIETTABILE IN SIRINGA PRE-RIEM
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041156035&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000046443","principiAttiviIt":["OCTREOTIDE ACETATO","OCTREOTIDE"],"confezioni":[{"idPackage":"127363","denominazionePackage":"\"0,5 MG/1 ML SOLUZIONE INIETTABI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=027083082&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000019548","principiAttiviIt":["OCTREOTIDE ACETATO","OCTREOTIDE"],"confezioni":[{"idPackage":"28512","denominazionePackage":"\"LAR 10 MG POLVERE E SOLVENTE PER
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=027104088&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[],"pageable":{"sort":{"sorted":false,"unsorted":true,"empty":true},"pageNumber":0,"pageSize":10,"offset":0,"unpaged":false,"paged":true},"last":true,"totalPages":0,"to
# ⚠️ No data found for AIC 27104088.0
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=047854017&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000058149","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"222998","denominazionePackage":"\"10 MG POLVERE E SOLVENTE PER SOSPENSIONE INIETTABILE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=027083094&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000019549","principiAttiviIt":["OCTREOTIDE ACETATO","OCTREOTIDE"],"confezioni":[{"idPackage":"28513","denominazionePackage":"\"LAR 20 MG POLVERE E SOLVENTE PER
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=027104090&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[],"pageable":{"sort":{"sorted":false,"unsorted":true,"empty":true},"pageNumber":0,"pageSize":10,"offset":0,"unpaged":false,"paged":true},"last":true,"totalPages":0,"to
# ⚠️ No data found for AIC 27104090.0
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=047854031&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000058150","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"223000","denominazionePackage":"\"20 MG POLVERE E SOLVENTE PER SOSPENSIONE INIETTABILE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=027083106&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000019550","principiAttiviIt":["OCTREOTIDE ACETATO","OCTREOTIDE"],"confezioni":[{"idPackage":"28514","denominazionePackage":"\" LAR 30 MG POLVERE E SOLVENTE PE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=027104102&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[],"pageable":{"sort":{"sorted":false,"unsorted":true,"empty":true},"pageNumber":0,"pageSize":10,"offset":0,"unpaged":false,"paged":true},"last":true,"totalPages":0,"to
# ⚠️ No data found for AIC 27104102.0
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=047854056&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000058151","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"223002","denominazionePackage":"\"30 MG POLVERE E SOLVENTE PER SOSPENSIONE INIETTABILE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040014019&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044193","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"111894","denominazionePackage":"\"0,05 MG/ML SOLUZIONE INIETTABILE O CONCENTRATO PER S
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040014021&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044194","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"111895","denominazionePackage":"\"0,1 MG/ML SOLUZIONE INIETTABILE O CONCENTRATO PER SO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040014033&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044195","principiAttiviIt":["OCTREOTIDE"],"confezioni":[{"idPackage":"111896","denominazionePackage":"\"0,5 MG/ML SOLUZIONE INIETTABILE O CONCENTRATO PER SO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=033638026&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000031608","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"58182","denominazionePackage":"\"2,5\" 100 COMPRESSE RIVESTITE 2,5 MG IN FLACONE USO O
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039034018&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000042396","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"102421","denominazionePackage":"\"2,5 MG - COMPRESSA RIVESTITA CON FILM - USO ORALE -
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039949019&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044061","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"111245","denominazionePackage":"\"2,5 MG COMPRESSE RIVESTITE CON FILM\" 28 COMPRESSE I
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040089029&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044346","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"112516","denominazionePackage":"\"2,5 MG COMPRESSE RIVESTITE CON FILM\" 10 COMPRESSE I
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040223012&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044607","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"114358","denominazionePackage":"\"2,5 MG COMPRESSE\" 28 COMPRESSE IN BLISTER AL/AL","d
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040333054&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044806","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"115774","denominazionePackage":"\"2,5 MG COMPRESSE RIVESTITE CON FILM\" 7 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040429033&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045008","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"117233","denominazionePackage":"\"2,5 MG COMPRESSE\" 7 COMPRESSE IN BLISTER PVC/PA/AL/
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040830022&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[],"pageable":{"sort":{"sorted":false,"unsorted":true,"empty":true},"pageSize":10,"pageNumber":0,"offset":0,"paged":true,"unpaged":false},"last":true,"totalPages":0,"to
# ⚠️ No data found for AIC 40830022.0
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040870014&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045859","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"123682","denominazionePackage":"\"2,5 MG COMPRESSE RIVESTITE\" 28 COMPRESSE IN BLISTER
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041598018&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000047286","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"132770","denominazionePackage":"\"2,5 MG COMPRESSE RIVESTITE CON FILM\" 28 COMPRESSE I
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042681015&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000049172","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"142808","denominazionePackage":"\"2,5 MG COMPRESSE\" 28 COMPRESSE IN BLISTER AL/AL","d
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=043547013&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000050750","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"149546","denominazionePackage":"2,5 MG -COMPRESSA - USO ORALE - BLISTER (ALU/ALU) - 28
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=047486016&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000057621","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"207560","denominazionePackage":"\"2,5 MG COMPRESSE RIVESTITE CON FILM\" 28 COMPRESSE I
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=033638038&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000031609","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"58184","denominazionePackage":"\"5\" 28 COMPRESSE RIVESTITE 5 MG IN BLISTER USO ORALE"
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=033638115&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000031612","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"58192","denominazionePackage":"\"VELOTAB\" 5 MG  28 COMPRESSE DISPERSIBILI USO ORALE I
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039034071&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000042397","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"102427","denominazionePackage":"\"5 MG - COMPRESSA RIVESTITA CON FILM - USO ORALE - BL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039949021&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044062","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"111246","denominazionePackage":"\"5 MG COMPRESSE RIVESTITE CON FILM\" 28 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039987019&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044143","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"111589","denominazionePackage":"\"5 MG COMPRESSE ORODISPERSIBILI\" 28 COMPRESSE IN BLI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040089056&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044347","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"112519","denominazionePackage":"\"5 MG COMPRESSE RIVESTITE CON FILM\" 10 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040223048&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044608","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"114361","denominazionePackage":"\"5 MG COMPRESSE\" 28 COMPRESSE IN BLISTER AL/AL","des
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040223190&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044608","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"114361","denominazionePackage":"\"5 MG COMPRESSE\" 28 COMPRESSE IN BLISTER AL/AL","des
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040333229&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044807","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"115791","denominazionePackage":"\"5 MG COMPRESSE RIVESTITE CON FILM\" 7 COMPRESSE IN B
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040429146&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045009","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"117244","denominazionePackage":"\"5 MG COMPRESSE\" 7 COMPRESSE IN BLISTER PVC/PA/AL/PV
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040470231&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000065563","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"117880","denominazionePackage":"¿5 MG - COMPRESSE ORODISPERSIBILI ¿ USO ORALE ¿ BLISTE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040532018&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045223","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"118795","denominazionePackage":"\"5 MG COMPRESSE ORODISPERSIBILI\" 28 COMPRESSE","desc
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040771115&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045686","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"122089","denominazionePackage":"\"5 MG COMPRESSE ORODISPERSIBILI\" 10 COMPRESSE IN BLI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040830061&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045787","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"122941","denominazionePackage":"\"5 MG COMPRESSE RIVESTITE CON FILM\" 14 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040830150&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000065567","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"122950","denominazionePackage":"\"5 MG COMPRESSE ORODISPERSIBILI\" 14 COMPRESSE IN BLI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040870053&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045860","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"123686","denominazionePackage":"\"5 MG COMPRESSE RIVESTITE\" 28 COMPRESSE IN BLISTER A
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040870255&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045865","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"123706","denominazionePackage":"\"5 MG COMPRESSE ORODISPERSIBILI\" 28 COMPRESSE IN BLI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041011077&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000046147","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"125244","denominazionePackage":"\" 5 MG-COMPRESSA-USO ORALE -BLISTER (AL/OPA/AL/PVC) \
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041011331&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000046147","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"125244","denominazionePackage":"\" 5 MG-COMPRESSA-USO ORALE -BLISTER (AL/OPA/AL/PVC) \
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041288010&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000046694","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"128902","denominazionePackage":"\" 5 MG COMPRESSE ORODISPERSIBILI \" 28 COMPRESSE IN B
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041598057&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000047287","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"132774","denominazionePackage":"\"5 MG COMPRESSE RIVESTITE CON FILM\" 28 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041954049&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000047899","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"135987","denominazionePackage":"\"5 MG COMPRESSE ORODISPERSIBILI\"  1 COMPRESSA IN BLI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042192017&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000048307","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"138087","denominazionePackage":"\"VELOTAB\" 5 MG 28 COMPRESSE DISPERSIBILI USO ORALE I
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042420012&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000048747","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"140728","denominazionePackage":"\"5 MG COMPRESSE ORODISPERSIBILI\" 28 COMPRESSE IN BLI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042681039&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000049173","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"142810","denominazionePackage":"\"5 MG COMPRESSE\" 28 COMPRESSE IN BLISTER AL/AL","des
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=043038013&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000049786","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"145092","denominazionePackage":"\"5 MG - COMPRESSA RIVESTITA CON FILM - USO ORALE - BL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=044423010&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000052582","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"157605","denominazionePackage":"\"VELOTAB\" 5 MG 28 COMPRESSE DISPERSIBILI USO ORALE I
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=045680016&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000054949","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"166570","denominazionePackage":"5 MG - COMPRESSA ORODISPERSIBILE - USO ORALE - BLISTER
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=045681018&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000054955","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"166580","denominazionePackage":"5 MG - COMPRESSA - USO ORALE - BLISTER (ALU/ALU) - 28
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=047486030&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000057622","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"207562","denominazionePackage":"\"5 MG COMPRESSE RIVESTITE CON FILM\" 28 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=047486117&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000065544","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"207570","denominazionePackage":"\"5 MG COMPRESSE ORODISPERSIBILI\" 28 COMPRESSE IN BLI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=033638091&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000031611","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"58188","denominazionePackage":"\"10\" 100 COMPRESSE  RIVESTITE 10 MG IN FLACONE USO OR
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=033638127&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000031613","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"58193","denominazionePackage":"\"VELOTAB\" 10 MG 28 COMPRESSE DISPERSIBILI USO ORALE I
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039034196&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000042399","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"102438","denominazionePackage":"\"10 MG COMPRESSA RIVESTITA CON FILM - USO ORALE - BLI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039949045&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044064","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"111248","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 28 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039987033&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044144","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"111591","denominazionePackage":"\"10 MG COMPRESSE ORODISPERSIBILI\" 28 COMPRESSE IN BL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040089132&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044348","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"112526","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 7 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040223101&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044610","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"114367","denominazionePackage":"\"10 MG COMPRESSE\" 28 COMPRESSE IN BLISTER AL/AL","de
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040223202&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044610","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"114367","denominazionePackage":"\"10 MG COMPRESSE\" 28 COMPRESSE IN BLISTER AL/AL","de
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040333395&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000044808","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"115808","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 7 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040429250&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045010","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"117255","denominazionePackage":"\"10 MG COMPRESSE\" 7 COMPRESSE IN BLISTER PVC/PA/AL/P
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040470270&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000065564","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"117884","denominazionePackage":"¿10 MG - COMPRESSE ORODISPERSIBILI ¿ USO ORALE ¿ BLIST
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040532020&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045224","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"118796","denominazionePackage":"\"10 MG COMPRESSE ORODISPERSIBILI\" 28 COMPRESSE","des
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040771267&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000065310","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"122105","denominazionePackage":"\"10 MG COMPRESSE ORODISPERSIBILI\" 10 COMPRESSE IN BL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040830109&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045788","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"122945","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 14 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040830212&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000065568","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"122956","denominazionePackage":"\"10 MG COMPRESSE ORODISPERSIBILI\" 14 COMPRESSE IN BL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040870139&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045862","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"123694","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE\" 28 COMPRESSE IN BLISTER
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040870293&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045866","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"123710","denominazionePackage":"\"10 MG COMPRESSE ORODISPERSIBILI\" 28 COMPRESSE IN BL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041011180&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000046149","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"125254","denominazionePackage":"\" 10 MG-COMPRESSA-USO ORALE -BLISTER (AL/OPA/AL/PVC)
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041011432&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000046149","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"125254","denominazionePackage":"\" 10 MG-COMPRESSA-USO ORALE -BLISTER (AL/OPA/AL/PVC)
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041288022&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000046695","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"128903","denominazionePackage":"\" 10 MG COMPRESSE ORODISPERSIBILI \" 28 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041598133&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000047289","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"132782","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 28 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=041954177&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000047900","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"136000","denominazionePackage":"\"10 MG COMPRESSE ORODISPERSIBILI\" 1 COMPRESSA IN BLI
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042420113&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000048748","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"140738","denominazionePackage":"\"10 MG COMPRESSE ORODISPERSIBILI\" 28 COMPRESSE IN BL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042681078&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000049175","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"142814","denominazionePackage":"\"10 MG COMPRESSE\" 28 COMPRESSE IN BLISTER AL/AL","de
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=045680030&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000054952","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"166572","denominazionePackage":"10 MG - COMPRESSA ORODISPERSIBILE - USO ORALE - BLISTE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=045681032&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000054958","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"166582","denominazionePackage":"10 MG - COMPRESSA - USO ORALE - BLISTER (ALU/ALU) - 28
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=047486067&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000057624","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"207565","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 28 COMPRESSE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=047486131&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000065545","principiAttiviIt":["OLANZAPINA"],"confezioni":[{"idPackage":"207572","denominazionePackage":"\"10 MG COMPRESSE ORODISPERSIBILI\" 28 COMPRESSE IN BL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=036025017&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000036505","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"72716","denominazionePackage":"28 COMPRESSE RIVESTITE CON FILM IN BLISTER AL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=036026019&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000036511","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"72731","denominazionePackage":"28 COMPRESSE RIVESTITE CON FILM IN BLISTER AL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=036027011&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000036516","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"72746","denominazionePackage":"28 COMPRESSE RIVESTITE CON FILM IN BLISTER AL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042368023&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000048652","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"140249","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 28 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=043112022&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000049915","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"145839","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 14 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=043236025&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[],"pageable":{"sort":{"sorted":false,"unsorted":true,"empty":true},"pageSize":10,"pageNumber":0,"offset":0,"paged":true,"unpaged":false},"last":true,"totalPages":0,"to
# ⚠️ No data found for AIC 43236025.0
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=043918046&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000051579","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"152607","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 10 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=043932021&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000051607","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"152761","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 14 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=044170025&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000052019","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"154014","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 14 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=044174023&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000052025","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"154036","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 14 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=044234033&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000052187","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"155376","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 28 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=044390021&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000052515","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"157224","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 14 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=044399044&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000052532","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"157325","denominazionePackage":"\" 10 MG COMPRESSE RIVESTITE CON FILM \" 7 C
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=044590026&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000052886","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"158806","denominazionePackage":"\" 10 MG COMPRESSE RIVESTITE CON FILM \" 14
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=045005016&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000053668","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"161730","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 28 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=045149010&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000053949","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"162971","denominazionePackage":"\" 10 MG COMPRESSE RIVESTITE CON FILM \" 28
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=049849019&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000062573","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"274451","denominazionePackage":"\"10 MG COMPRESSE RIVESTITE CON FILM\" 28 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=050058027&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000063072","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"275954","denominazionePackage":"\"10 mg COMPRESSE RIVESTITE CON FILM\" 14 CO
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=036025068&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000036507","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"72721","denominazionePackage":"28 COMPRESSE RIVESTITE CON FILM IN BLISTER AL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=036026060&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000036513","principiAttiviIt":["OLMESARTAN MEDOXOMIL"],"confezioni":[{"idPackage":"72736","denominazionePackage":"28 COMPRESSE RIVESTITE CON FILM IN BLISTER AL
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=036027062&spellingCorrection=true&page=0
# Status code: 200
# ...
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000049432","principiAttiviIt":["ACIDI OMEGA 3 ESTERI ETILICI 90"],"confezioni":[{"idPackage":"144044","denominazionePackage":"\"1000 MG CAPSULE MOLLI\" 20 CAPS
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042907016&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000049567","principiAttiviIt":["ACIDI OMEGA 3 ESTERI ETILICI 90"],"confezioni":[{"idPackage":"144389","denominazionePackage":"\" 1000 MG CAPSULE MOLLI \" 20 CA
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=044915015&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000053505","principiAttiviIt":["ACIDI OMEGA 3 ESTERI ETILICI 90"],"confezioni":[{"idPackage":"160901","denominazionePackage":"\"1000 MG CAPSULA MOLLE\" 20 CAPS
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=044916017&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000053506","principiAttiviIt":["ACIDI OMEGA 3 ESTERI ETILICI 90"],"confezioni":[{"idPackage":"160903","denominazionePackage":"\"1000 MG CAPSULE MOLLI\" 20 CAPS
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=045645013&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000054895","principiAttiviIt":["ACIDI OMEGA 3 ESTERI ETILICI 90"],"confezioni":[{"idPackage":"166361","denominazionePackage":"\"1000 MG CAPSULA MOLLE\" 20 CAPS
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=048331019&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000058905","principiAttiviIt":["ACIDI OMEGA 3 ESTERI ETILICI 90"],"confezioni":[{"idPackage":"237033","denominazionePackage":"\"1000 MG CAPSULE MOLLI\" 20 CAPS
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=048445011&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000059098","principiAttiviIt":["OMEGA 3 POLINSATURI"],"confezioni":[{"idPackage":"238563","denominazionePackage":"\"1000 MG CAPSULE MOLLI\" 20 CAPSULE IN BLIST
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=048489013&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000059168","principiAttiviIt":["OMEGA 3 POLINSATURI"],"confezioni":[{"idPackage":"240745","denominazionePackage":"\"1000 MG CAPSULE MOLLI\" 20 CAPSULE IN BLIST
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=048490015&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000059169","principiAttiviIt":["OMEGA 3 POLINSATURI"],"confezioni":[{"idPackage":"240747","denominazionePackage":"\"1000 MG CAPSULE MOLLI\" 20 CAPSULE IN BLIST
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=048491017&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000059170","principiAttiviIt":["OMEGA 3 POLINSATURI"],"confezioni":[{"idPackage":"240749","denominazionePackage":"\"1000 MG CAPSULE MOLLI\" 20 CAPSULE IN BLIST
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=048492019&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000059171","principiAttiviIt":["OMEGA 3 POLINSATURI"],"confezioni":[{"idPackage":"240751","denominazionePackage":"\"1000 MG CAPSULE MOLLI\" 20 CAPSULE IN BLIST
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=048819015&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000059584","principiAttiviIt":["ACIDI OMEGA 3 ESTERI ETILICI 90"],"confezioni":[{"idPackage":"252795","denominazionePackage":"\"1000 MG CAPSULE MOLLI\" 20 CAPS
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=026783086&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000018948","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"27346","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI \" 14 CAPSULE",
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=026803080&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000018982","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"27444","denominazionePackage":"«10 MG CAPSULE RIGIDE GASTRORESISTENTI» 14 CAPSULE IN B
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=026804082&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000018988","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"27473","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 14 CAPSULE","
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=028245114&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000022064","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"32579","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 14 CAPSULE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=037176017&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000038723","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"81888","denominazionePackage":"«10 MG CAPSULE RIGIDE GASTRORESISTENTI» 14 CAPSULE IN F
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=037623016&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000039626","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"87639","denominazionePackage":"\" 10 MG CAPSULE RIGIDE GASTRORESISTENTI \" 14 CAPSULE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=037623042&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000039626","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"87639","denominazionePackage":"\" 10 MG CAPSULE RIGIDE GASTRORESISTENTI \" 14 CAPSULE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=037665039&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000039716","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"87849","denominazionePackage":"\" 10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 14 CAPSULE",
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=038082020&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000040535","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"92623","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 7 CAPSULE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=038341018&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000041020","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"95403","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 14 CAPSULE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=038965024&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000042246","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"101603","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 7 CAPSULE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039610023&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000043457","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"108224","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 7 CAPSULE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=039758026&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000043699","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"109345","denominazionePackage":"\" 10 MG CAPSULE RIGIDE GASTRORESISTENTI \" 7 CAPSULE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=040880357&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000045883","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"123793","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 14 CAPSULE I
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042104657&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000048160","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"137359","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 7 CAPSULE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042236036&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000048383","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"138480","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 5 CAPSULE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042275014&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000048453","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"139168","denominazionePackage":"\"10 MG CAPSULA RIGIDA GASTRORESISTENTE\" 14 CAPSULE",
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042276016&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000048456","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"139174","denominazionePackage":"10 MG CAPSULA RIGIDA GASTRORESISTENTE  14 CAPSULE","de
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=042548014&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[],"pageable":{"sort":{"sorted":false,"unsorted":true,"empty":true},"pageNumber":0,"pageSize":10,"offset":0,"unpaged":false,"paged":true},"last":true,"totalPages":0,"to
# ⚠️ No data found for AIC 42548014.0
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=043490135&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000050629","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"149203","denominazionePackage":"\" 10MG CAPSULE RIGIDE GASTRORESISTENTI \" 14 CAPSULE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=043498017&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000050646","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"149327","denominazionePackage":"\"10 MG CAPSULE RIGIDE GASTRORESISTENTI\" 14 CAPSULE I
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=026783098&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000018949","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"27347","denominazionePackage":"\"20 MG CAPSULE RIGIDE GASTRORESISTENTI\" 14 CAPSULE","
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=026803104&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000018983","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"27446","denominazionePackage":"«20 MG CAPSULE RIGIDE GASTRORESISTENTI» 14 CAPSULE IN B
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=026804106&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000018990","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"27475","denominazionePackage":"\"20 MG CAPSULE RIGIDE GASTRORESISTENTI\" 14 CAPSULE","
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=028245090&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000022062","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"32578","denominazionePackage":"\"20 MG CAPSULE RIGIDE GASTRORESISTENTI\" 14 CAPSULE IN
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=037176029&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000038724","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"81889","denominazionePackage":"«20 MG CAPSULE RIGIDE GASTRORESISTENTI» 14 CAPSULE IN F
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=037623028&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000039627","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"87640","denominazionePackage":"\" 20 MG CAPSULE RIGIDE GASTRORESISTENTI \" 14 CAPSULE
# Trying URL: https://api.aifa.gov.it/aifa-bdf-eif-be/1.0.0/formadosaggio/ricerca?query=037623055&spellingCorrection=true&page=0
# Status code: 200
# Content-Type: application/json
# Response snippet: {"status":200,"data":{"content":[{"id":"0000039627","principiAttiviIt":["OMEPRAZOLO"],"confezioni":[{"idPackage":"87640","denominazionePackage":"\" 20 MG CAPSULE RIGIDE GASTRORESISTENTI \" 14 CAPSULE
# AIC codes with no results: ['27104088.0', '27104090.0', '27104102.0', '40830022.0', '43236025.0', '43236088.0', '43236140.0', '42548014.0']
# Dropped 8 rows without codiceSis.
# Saved dataset with URLs, total rows: 325

# %%
import os
import requests
from tqdm import tqdm
import pandas as pd

pdf_folder = '/content/aifa_pdfs'
os.makedirs(pdf_folder, exist_ok=True)

df = pd.read_csv('/content/final_filtered_dataset_with_urls.csv')

for idx, row in tqdm(df.iterrows(), total=len(df)):
    url = row['URL']
    aic_code = str(row['AIC']).split('.')[0]  # remove trailing '.0' if any

    try:
        response = requests.get(url, timeout=15)
        if response.status_code == 200:
            if response.content[:4] == b'%PDF':
                pdf_path = os.path.join(pdf_folder, f"{aic_code}.pdf")
                with open(pdf_path, 'wb') as f:
                    f.write(response.content)
            else:
                print(f"Skipping AIC {aic_code}: Content does not look like PDF. Possibly HTML or error page.")
        else:
            print(f"Skipping AIC {aic_code}: HTTP status {response.status_code}")

    except Exception as e:
        print(f"Error downloading AIC {aic_code}: {e}")


# After download, check which PDFs are missing

pdf_files = set(f.replace('.pdf', '') for f in os.listdir(pdf_folder) if f.endswith('.pdf'))
dataset_aics = set(df['AIC'].astype(str).str.split('.').str[0])  # remove trailing '.0' if any

missing_aics = dataset_aics - pdf_files

print(f"Number of missing PDFs: {len(missing_aics)}")
print("Missing AIC codes:")
print(missing_aics)




'''!pip install pymupdf
import os
import re
import fitz  # PyMuPDF
import pandas as pd
from tqdm import tqdm

# --- CONFIGURATION ---
pdf_folder = '/content/extracted_aifae.xlsx'

# --- Sections to extract ---
sections_to_extract = [
    "4.1 Therapeutic indications",
    "4.2 Posology and method of administration",
    "4.3 Contraindications",
    "4.4 Special warnings and precautions for use",
    "4.5 Interactions with other medicinal products",
    "4.6 Fertility, pregnancy and lactation",
    "4.7 Effects on ability to drive and use machines",
    "4.8 Undesirable effects",
    "4.9 Overdose",
    "6.2 Incompatibilities"
]

# Precompile regex for section headings
section_regex = re.compile(r"(4\.1|4\.2|4\.3|4\.4|4\.5|4\.6|4\.7|4\.8|4\.9|6\.2)\s+([^\n]+)", re.IGNORECASE)

# --- Function to extract section text ---
def extract_sections_from_text(text):
    matches = list(section_regex.finditer(text))
    section_dict = {}

    for i, match in enumerate(matches):
        section_num = match.group(1)
        section_title = match.group(2).strip()
        section_key = f"{section_num} {section_title}"
        section_key_clean = next((s for s in sections_to_extract if s.lower().startswith(section_num)), None)
        if not section_key_clean:
            continue
        start = match.end()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
        section_text = text[start:end].strip()
        section_dict[section_key_clean] = section_text

    # Add missing sections as "Not found"
    for s in sections_to_extract:
        if s not in section_dict:
            section_dict[s] = "Not found"

    return section_dict

# --- Process all PDFs ---
data = []
pdf_files = sorted(f for f in os.listdir(pdf_folder) if f.lower().endswith(".pdf"))

for filename in tqdm(pdf_files, desc="Processing PDFs"):
    aic = filename.replace(".pdf", "").lstrip('0')  # <-- remove leading zeros from filename
    pdf_path = os.path.join(pdf_folder, filename)
    try:
        doc = fitz.open(pdf_path)
        full_text = ""
        for page in doc:
            full_text += page.get_text()
        doc.close()

        extracted = extract_sections_from_text(full_text)
        extracted["AIC"] = aic  # <-- store AIC without leading zeros
        data.append(extracted)

    except Exception as e:
        print(f"Error processing {filename}: {e}")

# --- Save to Excel ---
df = pd.DataFrame(data)
df = df[["AIC"] + sections_to_extract]  # Column order
df.to_excel(output_file, index=False)

print(f"\n✅ Extraction complete. File saved to:\n{output_file}")
'''
# Out:
#  19%|█▉        | 61/325 [01:28<05:37,  1.28s/it]
# Skipping AIC 42192017: HTTP status 404
#  20%|█▉        | 64/325 [01:32<05:09,  1.19s/it]
# Skipping AIC 43038013: HTTP status 404
#  20%|██        | 65/325 [01:32<04:32,  1.05s/it]
# Skipping AIC 44423010: HTTP status 404
#  32%|███▏      | 104/325 [02:32<04:38,  1.26s/it]
# Skipping AIC 43932021: HTTP status 404
#  33%|███▎      | 107/325 [02:36<04:25,  1.22s/it]
# Skipping AIC 44234033: HTTP status 404
#  34%|███▎      | 109/325 [02:38<04:03,  1.13s/it]
# Skipping AIC 44399044: HTTP status 404
#  34%|███▍      | 110/325 [02:39<03:47,  1.06s/it]
# Skipping AIC 44590026: HTTP status 404
#  35%|███▌      | 114/325 [02:44<04:03,  1.15s/it]
# Skipping AIC 50058027: HTTP status 404
#  37%|███▋      | 121/325 [02:54<04:07,  1.21s/it]
# Skipping AIC 43932058: HTTP status 404
#  38%|███▊      | 124/325 [02:57<03:56,  1.18s/it]
# Skipping AIC 44234146: HTTP status 404
#  39%|███▉      | 126/325 [02:59<03:35,  1.08s/it]
# Skipping AIC 44399119: HTTP status 404
#  39%|███▉      | 127/325 [03:00<03:12,  1.03it/s]
# Skipping AIC 44590091: HTTP status 404
#  40%|████      | 131/325 [03:05<03:34,  1.11s/it]
# Skipping AIC 50058066: HTTP status 404
#  42%|████▏     | 138/325 [03:15<03:44,  1.20s/it]
# Skipping AIC 43932084: HTTP status 404
#  43%|████▎     | 141/325 [03:19<03:45,  1.23s/it]
# Skipping AIC 44234250: HTTP status 404
#  44%|████▍     | 143/325 [03:21<03:29,  1.15s/it]
# Skipping AIC 44399184: HTTP status 404
#  44%|████▍     | 144/325 [03:22<03:05,  1.02s/it]
# Skipping AIC 44590166: HTTP status 404
#  46%|████▌     | 148/325 [03:27<03:26,  1.17s/it]
# Skipping AIC 50058116: HTTP status 404
#  48%|████▊     | 157/325 [03:39<03:27,  1.24s/it]
# Skipping AIC 45512100: HTTP status 404
#  50%|████▉     | 162/325 [03:47<03:24,  1.25s/it]
# Skipping AIC 49444019: HTTP status 404
#  53%|█████▎    | 171/325 [03:59<03:05,  1.21s/it]
# Skipping AIC 45512403: HTTP status 404
#  54%|█████▍    | 176/325 [04:06<03:07,  1.26s/it]
# Skipping AIC 49444033: HTTP status 404
#  57%|█████▋    | 185/325 [04:18<02:51,  1.22s/it]
# Skipping AIC 45512252: HTTP status 404
#  58%|█████▊    | 190/325 [04:25<02:42,  1.21s/it]
# Skipping AIC 49444021: HTTP status 404
#  59%|█████▉    | 192/325 [04:27<02:34,  1.16s/it]
# Skipping AIC 47997010: HTTP status 404
#  60%|██████    | 196/325 [04:32<02:34,  1.20s/it]
# Skipping AIC 47997034: HTTP status 404
#  62%|██████▏   | 200/325 [04:38<02:32,  1.22s/it]
# Skipping AIC 47997073: HTTP status 404
#  63%|██████▎   | 204/325 [04:43<02:20,  1.16s/it]
# Skipping AIC 47997059: HTTP status 404
#  64%|██████▍   | 208/325 [04:48<02:23,  1.23s/it]
# Skipping AIC 47997097: HTTP status 404
#  67%|██████▋   | 219/325 [05:04<02:13,  1.26s/it]
# Skipping AIC 44588022: HTTP status 404
#  72%|███████▏  | 235/325 [05:28<01:54,  1.27s/it]
# Skipping AIC 44588061: HTTP status 404
#  81%|████████  | 263/325 [06:17<01:20,  1.29s/it]
# Skipping AIC 44588147: HTTP status 404
# 100%|██████████| 325/325 [07:59<00:00,  1.47s/it]
# Number of missing PDFs: 32
# Missing AIC codes:
# {'44588061', '43038013', '47997034', '50058116', '47997073', '44423010', '50058027', '44590166', '49444021', '47997010', '45512100', '44234250', '44399184', '47997059', '44399044', '44590091', '45512403', '44588147', '44234146', '44588022', '45512252', '43932084', '43932021', '50058066', '43932058', '47997097', '44590026', '49444033', '42192017', '49444019', '44234033', '44399119'}
# '!pip install pymupdf\nimport os\nimport re\nimport fitz  # PyMuPDF\nimport pandas as pd\nfrom tqdm import tqdm\n\n# --- CONFIGURATION ---\npdf_folder = \'/content/extracted_aifae.xlsx\'\n\n# --- Sections to extract ---\nsections_to_extract = [\n    "4.1 Therapeutic indications",\n    "4.2 Posology and method of administration",\n    "4.3 Contraindications",\n    "4.4 Special warnings and precautions for use",\n    "4.5 Interactions with other medicinal products",\n    "4.6 Fertility, pregnancy and lactation",\n    "4.7 Effects on ability to drive and use machines",\n    "4.8 Undesirable effects",\n    "4.9 Overdose",\n    "6.2 Incompatibilities"\n]\n\n# Precompile regex for section headings\nsection_regex = re.compile(r"(4\\.1|4\\.2|4\\.3|4\\.4|4\\.5|4\\.6|4\\.7|4\\.8|4\\.9|6\\.2)\\s+([^\n]+)", re.IGNORECASE)\n\n# --- Function to extract section text ---\ndef extract_sections_from_text(text):\n    matches = list(section_regex.finditer(text))\n    section_dict = {}\n\n    for i, match in enumerate(matches):\n        section_num = match.group(1)\n        section_title = match.group(2).strip()\n        section_key = f"{section_num} {section_title}"\n        section_key_clean = next((s for s in sections_to_extract if s.lower().startswith(section_num)), None)\n        if not section_key_clean:\n            continue\n        start = match.end()\n        end = matches[i + 1].start() if i + 1 < len(matches) else len(text)\n        section_text = text[start:end].strip()\n        section_dict[section_key_clean] = section_text\n\n    # Add missing sections as "Not found"\n    for s in sections_to_extract:\n        if s not in section_dict:\n            section_dict[s] = "Not found"\n\n    return section_dict\n\n# --- Process all PDFs ---\ndata = []\npdf_files = sorted(f for f in os.listdir(pdf_folder) if f.lower().endswith(".pdf"))\n\nfor filename in tqdm(pdf_files, desc="Processing PDFs"):\n    aic = filename.replace(".pdf", "").lstrip(\'0\')  # <-- remove leading zeros from filename\n    pdf_path = os.path.join(pdf_folder, filename)\n    try:\n        doc = fitz.open(pdf_path)\n        full_text = ""\n        for page in doc:\n            full_text += page.get_text()\n        doc.close()\n\n        extracted = extract_sections_from_text(full_text)\n        extracted["AIC"] = aic  # <-- store AIC without leading zeros\n        data.append(extracted)\n\n    except Exception as e:\n        print(f"Error processing {filename}: {e}")\n\n# --- Save to Excel ---\ndf = pd.DataFrame(data)\ndf = df[["AIC"] + sections_to_extract]  # Column order\ndf.to_excel(output_file, index=False)\n\nprint(f"\n✅ Extraction complete. File saved to:\n{output_file}")\n'

# %%
# !pip install PyMuPDF
pdf_folder = '/content/aifa_pdfs'
output_file = '/content/extracted_aifa.xlsx'  # output Excel file

import os
import re
import fitz  # PyMuPDF
import pandas as pd
from tqdm import tqdm


pdf_folder = '/content/aifa_pdfs'
pdf_files = [f for f in os.listdir(pdf_folder) if f.lower().endswith('.pdf')]
print(f"Number of PDF files found in folder: {len(pdf_files)}")

# Sections to extract
sections_to_extract = [
    "4.1 Therapeutic indications",
    "4.2 Posology and method of administration",
    "4.3 Contraindications",
    "4.4 Special warnings and precautions for use",
    "4.5 Interactions with other medicinal products",
    "4.6 Fertility, pregnancy and lactation",
    "4.7 Effects on ability to drive and use machines",
    "4.8 Undesirable effects",
    "4.9 Overdose",
    "6.2 Incompatibilities"
]

# Precompile regex for section headings
section_regex = re.compile(r"(4\.1|4\.2|4\.3|4\.4|4\.5|4\.6|4\.7|4\.8|4\.9|6\.2)\s+([^\n]+)", re.IGNORECASE)

def extract_sections_from_text(text):
    matches = list(section_regex.finditer(text))
    section_dict = {}

    for i, match in enumerate(matches):
        section_num = match.group(1)
        section_title = match.group(2).strip()
        section_key = f"{section_num} {section_title}"
        section_key_clean = next((s for s in sections_to_extract if s.lower().startswith(section_num)), None)
        if not section_key_clean:
            continue
        start = match.end()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
        section_text = text[start:end].strip()
        section_dict[section_key_clean] = section_text

    # Fill missing sections with "Not available"
    for s in sections_to_extract:
        if s not in section_dict:
            section_dict[s] = "Not available"

    return section_dict

# Process PDFs and extract sections
data = []
pdf_files = sorted(f for f in os.listdir(pdf_folder) if f.lower().endswith(".pdf"))

for filename in tqdm(pdf_files, desc="Processing PDFs"):
    aic = filename.replace(".pdf", "").lstrip('0')
    pdf_path = os.path.join(pdf_folder, filename)
    try:
        doc = fitz.open(pdf_path)
        full_text = ""
        for page in doc:
            full_text += page.get_text()
        doc.close()

        extracted = extract_sections_from_text(full_text)
        extracted["AIC"] = aic
        data.append(extracted)

    except Exception as e:
        print(f"❌ Error processing {filename}: {e}")  # <-- Add this line for debugging

# Save extracted sections to Excel
df = pd.DataFrame(data)
df = df[["AIC"] + sections_to_extract]  # specify column order
df.to_excel(output_file, index=False)

print(f"\n✅ Extraction complete. Saved to:\n{output_file}")


pdf_folder = '/content/aifa_pdfs'
pdf_files = set(f.replace('.pdf', '').lstrip('0') for f in os.listdir(pdf_folder) if f.endswith('.pdf'))

# Load your CSV dataset with all AICs
df_clean = pd.read_csv('/content/final_filtered_dataset_with_urls.csv', dtype={'AIC': str})

# Normalize AICs by stripping leading zeros to match file naming
dataset_aics = set(df_clean['AIC'].astype(str).str.lstrip('0'))

missing_aics = dataset_aics - pdf_files

print(f"Number of missing PDFs: {len(missing_aics)}")
print("Missing AIC codes:", missing_aics)
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.0-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 48.3 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.26.0
# Number of PDF files found in folder: 293
# Processing PDFs: 100%|██████████| 293/293 [01:10<00:00,  4.18it/s]
# ✅ Extraction complete. Saved to:
# /content/extracted_aifa.xlsx
# Number of missing PDFs: 325
# Missing AIC codes: {'44319299.0', '40870053.0', '47486117.0', '40223190.0', '44390021.0', '36027112.0', '44319426.0', '41011077.0', '36027011.0', '44234146.0', '27616022.0', '48491017.0', '41156011.0', '45710011.0', '40771115.0', '48464010.0', '44319034.0', '40333229.0', '47997010.0', '47486030.0', '38341018.0', '48464046.0', '44399044.0', '47488147.0', '44174187.0', '42192017.0', '48492021.0', '38965024.0', '28245114.0', '38983247.0', '26804082.0', '40429146.0', '37109131.0', '36892053.0', '45934130.0', '43038013.0', '43490135.0', '40223012.0', '39987019.0', '39949021.0', '50058027.0', '42368023.0', '46184038.0', '33638127.0', '26803104.0', '45645013.0', '44319162.0', '44411496.0', '42825012.0', '40089132.0', '36160152.0', '37665039.0', '40223202.0', '37110362.0', '40223048.0', '47486016.0', '38947139.0', '50058116.0', '42368035.0', '39100019.0', '36026060.0', '48819015.0', '27617024.0', '39100045.0', '45120159.0', '45681018.0', '44538116.0', '36026110.0', '40532020.0', '42907016.0', '33638115.0', '40333054.0', '45680030.0', '45149022.0', '28687010.0', '42432056.0', '45934039.0', '40014045.0', '45340128.0', '44232130.0', '45398029.0', '48464022.0', '37623055.0', '44916029.0', '45398031.0', '45832019.0', '45512100.0', '49849019.0', '39987033.0', '45832058.0', '41598057.0', '37109244.0', '44232231.0', '39101011.0', '49860012.0', '40089029.0', '42368047.0', '45197163.0', '45149034.0', '41954049.0', '48492019.0', '41011180.0', '43932058.0', '40223101.0', '39034196.0', '43547013.0', '37110246.0', '43918248.0', '26804106.0', '49375013.0', '45151038.0', '45197237.0', '41598018.0', '44922021.0', '45162082.0', '39610023.0', '40089056.0', '48464059.0', '45119120.0', '38946137.0', '26783086.0', '39101074.0', '44390223.0', '45120021.0', '47488085.0', '49444019.0', '27083082.0', '40710016.0', '49375076.0', '40333395.0', '39101047.0', '42681039.0', '44538433.0', '49375138.0', '48489013.0', '38947242.0', '42637013.0', '42639029.0', '36160164.0', '40014019.0', '39034071.0', '44390122.0', '39100072.0', '40880357.0', '44411344.0', '42236036.0', '42432070.0', '42420113.0', '40470231.0', '37109360.0', '48464034.0', '48331021.0', '45129018.0', '49849021.0', '48490027.0', '27618040.0', '44588022.0', '44855070.0', '50058066.0', '41156047.0', '44232332.0', '44538270.0', '36025068.0', '43918046.0', '38983021.0', '33638026.0', '36160188.0', '43918147.0', '47854031.0', '42637025.0', '45710124.0', '41954177.0', '49849033.0', '44174100.0', '44855029.0', '28687034.0', '44234033.0', '44399184.0', '40830150.0', '45149010.0', '44232039.0', '47488022.0', '28687022.0', '42275014.0', '45120096.0', '49860036.0', '37176017.0', '40870139.0', '26803080.0', '47854017.0', '44411027.0', '40014033.0', '45680016.0', '43932084.0', '37110020.0', '49860024.0', '48819027.0', '44588061.0', '44538597.0', '44590026.0', '48445011.0', '40870014.0', '49444021.0', '39949019.0', '46184026.0', '41598133.0', '44590091.0', '37108026.0', '44375121.0', '44375323.0', '36025017.0', '45151014.0', '46184014.0', '47997073.0', '42639017.0', '44423010.0', '44922146.0', '38946012.0', '42681078.0', '45197098.0', '37108139.0', '44170025.0', '40771267.0', '41156035.0', '47997097.0', '45119031.0', '40429250.0', '45162029.0', '47997034.0', '37623042.0', '40830212.0', '47488200.0', '47486131.0', '40870255.0', '49806173.0', '45005016.0', '26783098.0', '40429033.0', '49806072.0', '37623028.0', '37110133.0', '45512252.0', '45398017.0', '42681015.0', '44922209.0', '45005028.0', '49806021.0', '43112097.0', '49806122.0', '40470270.0', '37109028.0', '44170102.0', '44588147.0', '39034018.0', '47486067.0', '44411181.0', '47997059.0', '37108368.0', '45934231.0', '44922084.0', '36892089.0', '42638015.0', '45512403.0', '37623016.0', '28245090.0', '40830109.0', '38983161.0', '48490015.0', '39758026.0', '45119221.0', '47488263.0', '45681032.0', '40830061.0', '42276016.0', '44590166.0', '45197023.0', '45162144.0', '41288022.0', '47854056.0', '49444033.0', '38947026.0', '33638091.0', '43112022.0', '49860048.0', '421 ...
